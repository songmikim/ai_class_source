# %%
# !pip install tensorflow-hub
# Out:
# ...
#   Using cached tensorflow_hub-0.16.1-py2.py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached tf_keras-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# ...
# Using cached tensorflow_hub-0.16.1-py2.py3-none-any.whl (30 kB)
# Using cached tf_keras-2.19.0-py3-none-any.whl (1.7 MB)
# ...
#
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
# ...

# %%
# !pip install tf-keras==2.17.0   # 오류나는 경우 cmd관리자권한으로 설치
# Out:
# ...
#   Using cached tf_keras-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached tensorflow-2.17.1-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# ...
#   Using cached tensorflow_intel-2.17.1-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# ...
# Using cached tf_keras-2.17.0-py3-none-any.whl (1.7 MB)
# Using cached tensorflow-2.17.1-cp312-cp312-win_amd64.whl (7.5 kB)
# Using cached tensorflow_intel-2.17.1-cp312-cp312-win_amd64.whl (382.4 MB)
# ...
#
#    ---------------------------------------- 0/3 [tensorflow-intel]
#    ---------------------------------------- 0/3 [tensorflow-intel]
#
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'c:\\Users\\admin\\Desktop\\김송미\\09_머신러닝\\source\\.venv\\Lib\\site-packages\\tensorflow\\compiler\\mlir\\lite\\python\\_pywrap_converter_api.pyd'
# Check the permissions.

# %%
# !pip install tensorflow
# Out:
# ...
#   Using cached tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached ml_dtypes-0.5.1-cp312-cp312-win_amd64.whl.metadata (22 kB)
# ...
# Using cached ml_dtypes-0.5.1-cp312-cp312-win_amd64.whl (210 kB)
# Using cached tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
# ...
#
#   Attempting uninstall: ml-dtypes
#
#     Found existing installation: ml-dtypes 0.4.1
#
#     Uninstalling ml-dtypes-0.4.1:
#
#       Successfully uninstalled ml-dtypes-0.4.1
#
#   Attempting uninstall: tensorboard
#
#     Found existing installation: tensorboard 2.17.1
#
#    -------------------- ------------------- 1/2 [tensorboard]
#     Uninstalling tensorboard-2.17.1:
#    -------------------- ------------------- 1/2 [tensorboard]
#       Successfully uninstalled tensorboard-2.17.1
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
# ...

# %%
import tensorflow_hub as hub
import tensorflow as keras
# Out:
#   Cell In[5], line 2
#     import tf-keras as keras
#              ^
# SyntaxError: invalid syntax
