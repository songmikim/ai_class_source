# %%
import numpy as np
fruits = np.array(['사과','오렌지', '멜론', '망고'])

# %%
fruits[[False, True, True, False]]
# Out:
# array(['오렌지', '멜론'], dtype='<U3')

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(-5, 5, 0.1)
y = 1 / (1 + np.exp(-x))

# %%
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()
